# %% [markdown]
# ### Data & multiple containers are important when dockerizing you entire application

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Theres so many files to keep track of! **Use one master file! DOCKER COMPOSE**
