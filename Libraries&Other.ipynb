# %% [markdown]
# ### pandas
#
# high-level library for data manipulation and analysis in Python. It provides efficient and easy-to-use data structures like DataFrame and Series that are designed to handle and process large datasets with ease. It is particularly useful for working with structured data (i.e., data that is organized in tables, spreadsheets, or databases).
#
# 1. Data Structures: Series (1D) and DataFrame (2D) for handling structured data.
# 2. Data Manipulation: Indexing, selection, filtering, and sorting data.
# 3. Handling Missing Data: Functions like isna(), dropna(), and fillna().
# 4. Grouping and Aggregation: Using groupby() to group data and perform aggregation.
# 5. Merging and Joining: Merging datasets with merge() and concatenating with concat().
# 6. Time Series: Handling time-based data with built-in date/time functionality.
# 7. Reading and Writing Data: Reading/writing from formats like CSV, Excel, and SQL.
# 8. Data Transformation: Reshaping data, applying functions, and converting data types.
#
# - Series: A one-dimensional labeled array (similar to a list or a 1D array in NumPy). It can hold any data type (integers, strings, floats, etc.) and is often used for individual columns or rows in a dataset.
# - DataFrame: A two-dimensional, size-mutable, and potentially heterogeneous tabular data structure (similar to a table, Excel spreadsheet, or SQL table). It is the most commonly used object in pandas and provides both row and column labels.

# %% [markdown]
# **creating dataframe**

# %%
import pandas as pd

# Creating a DataFrame from a dictionary
data = {'Name': ['Alice', 'Bob', 'Charlie'],
        'Age': [24, 27, 22],
        'City': ['New York', 'San Francisco', 'Los Angeles']}
df = pd.DataFrame(data)

print(df)

# %% [markdown]
# **reading and writing data**

# %%
# Reading from a CSV file
df = pd.read_csv('data.csv')

# Writing to a CSV file
df.to_csv('output.csv', index=False)

# %% [markdown]
# **basic operations**

# %%
# Displaying basic info
print(df.head())  # First 5 rows
print(df.describe())  # Summary statistics

# Accessing columns and rows
print(df['Name'])  # Access column 'Name'
print(df.loc[0])  # Access the first row

# %% [markdown]
# **merging dataframes**

# %%
# Merging two DataFrames on a common column 'Name'
df1 = pd.DataFrame({'Name': ['Alice', 'Bob'], 'Age': [24, 27]})
df2 = pd.DataFrame({'Name': ['Alice', 'Bob'], 'City': ['New York', 'San Francisco']})

merged_df = pd.merge(df1, df2, on='Name')
print(merged_df)

# %% [markdown]
# **selecting data**

# %%
# Select rows where Age is greater than 23
filtered_df = df[df['Age'] > 23]

# Select specific columns
subset_df = df[['Name', 'Age']]

# %% [markdown]
# ### matplotlib
# Powerful plotting and visualization library for Python that allows you to create a wide range of static, animated, and interactive plots and charts. It is primarily used for data visualization, making it a common choice in data analysis, machine learning, and scientific computing.
#
# NumPy and PyPlot (part of matplotlib) are both used for scientific computing and data visualization in Python, but they serve very different purposes. Here’s a breakdown of their key differences:
# 1. Purpose:
#
# - NumPy: A fundamental package for numerical computing. It provides support for working with large, multi-dimensional arrays and matrices, along with a collection of mathematical functions to operate on these arrays. NumPy is not a part of matplotlib by default, so you need to install it separately if you plan to use it for numerical operations.
# - PyPlot: Part of the matplotlib library, PyPlot is specifically used for creating static, interactive, and animated plots and visualizations. It is primarily concerned with plotting data and visualizing it.

# %% [markdown]
# ### Pyplot
# A module within the matplotlib library that provides a collection of functions for generating plots in a style similar to MATLAB. It's designed to make plotting easier and more accessible, especially for beginners.
# has functions like:
# - plot(): Creates a line plot.
# - scatter(): Creates a scatter plot.
# - bar(): Creates a bar chart.
# - xlabel(), ylabel(): Add labels to axes.
# - title(): Add a title to the plot.
# - show(): Display the plot.

# %%
import matplotlib.pyplot as plt

# Data
x = [1, 2, 3, 4, 5]
y = [1, 4, 9, 16, 25]

# Create a plot
plt.plot(x, y, label="y = x^2", color='blue', marker='o')

# Add labels and title
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.title('Example of Line Plot')

# Add a legend
plt.legend()

# Show the plot
plt.show()

# %% [markdown]
# ### NumPy
# provides support for large, multi-dimensional arrays and matrices, along with a collection of mathematical functions to operate on these arrays. It is one of the core libraries for data science, machine learning, and scientific computing in Python.

# %%
import numpy as np

# Creating a 1D array
arr = np.array([1, 2, 3, 4])

# Performing element-wise operations
arr = arr * 2  # Multiplies each element by 2

print(arr)

# %% [markdown]
# ### pathlib
#
# Flexible way to handle paths, compared to older methods like os.path.

# %%
from pathlib import Path

# Create a Path object
path = Path("folder") / "subfolder" / "file.txt"

# Check if the path exists
if path.exists():
    print(f"{path} exists!")
else:
    print(f"{path} does not exist.")

# Get the parent directory
parent_dir = path.parent
print(f"Parent Directory: {parent_dir}")

# Read contents from a file (if it's a text file)
if path.exists() and path.is_file():
    with path.open("r") as file:
        content = file.read()
        print(content)

# %% [markdown]
# ## **Quix Streams** (from quixstreams import Application)
#
# QuixStreams is a real-time data streaming platform that is designed for handling large-scale, high-performance, and low-latency data streams. It allows developers and data engineers to easily process, analyze, and deliver real-time data streams from various sources likr Kafka (e.g., IoT devices, Kafka, databases, sensors) to destinations like databases, data lakes, etc
#
# **What is Application in Quix Streams?**
# In Quix Streams, Application is a class that helps you connect to Kafka and interact with topics.
#
# **What Quix Streams Does**
# - Simplifies Kafka operations (producing & consuming messages).
# - Works natively with Python, making real-time data processing easier.
# - Manages data streams efficiently, handling topics, serialization, and event-driven processing.
#
# ### Work in Kafka & Quix Streams
#
# - Serializer (Encoding Data for Kafka)
#     A serializer converts a Python object (like a dictionary) into a format that can be sent over a network or stored (e.g., JSON or binary). Converts Python data (e.g., a dictionary) into a format Kafka can send.
#
# - Deserializer (Decoding Received Data)
#     A deserializer does the opposite—it converts received data back into a Python object. It converts raw Kafka data (JSON, binary, etc.) into a Python object.
#
# ---

# %% [markdown]
# ## **Docker Hub**
#
# 🚀 Docker Hub is a cloud-based repository for Docker images, where you can find, store, and share container images. Think of it like GitHub for Docker images—a place where developers and teams can store, pull, and push images to run applications in Docker containers.
#
# **Docker Hub hosts millions of prebuilt container images, including official images like:**
#
#     - PostgreSQL → postgres
#     - Kafka → confluentinc/cp-kafka
#
# 🛠️**How Docker Hub Works**
#
# 1. Find an image → Search for an image on [Docker Hub](https://hub.docker.com/)
# 2. Pull the image → Download it using docker pull
# 3. Run a container → Start a container with docker run
# 4. Modify & Push → Build and push your own custom images
#
# **PULL & RUN images:**
# - docker pull postgres  #Pulls the latest PostgreSQL image
# - docker run -d --name my-postgres -e POSTGRES_PASSWORD=mysecretpassword -p 5432:5432 postgres
#
#
# ---

# %% [markdown]
# ### os
# If you are working with older Python code or libraries that use os.path, it might be simpler to stick with os to maintain consistency and avoid introducing additional changes.

# %% [markdown]
# ### json
#
# Purpose: Provides methods to work with JSON (JavaScript Object Notation), including parsing JSON strings and serializing Python objects into JSON format.
# Common Functions:
# - json.dumps(): Convert Python objects to JSON strings
# - json.loads(): Parse JSON strings into Python objects
# - json.dump(), json.load(): Read/write JSON data from/to files

# %% [markdown]
# ### re
#
# Purpose: used for working with regular expressions, which allow for pattern matching in strings. You can use it to search, match, and manipulate strings based on specific patterns.
# Common Functions:
#
# - re.match(), re.search(), re.findall(): Search for patterns in strings
# - re.sub(): Replace parts of strings matching a regular expression

# %%
import re

text = "The quick brown fox jumps over the lazy dog."

# 1. re.search() - Find pattern
if re.search(r'fox', text):
    print("Found 'fox'")

# 2. re.findall() - Find all 4-letter words
print("4-letter words:", re.findall(r'\b\w{4}\b', text))

# 3. re.sub() - Replace 'dog' with 'cat'
print("Updated text:", re.sub(r'dog', 'cat', text))

# 4. re.match() - Check if string starts with 'The'
if re.match(r'The', text):
    print("Starts with 'The'")
# Out:
# Found 'fox'
# 4-letter words: ['over', 'lazy']
# Updated text: The quick brown fox jumps over the lazy cat.
# Starts with 'The'

# %% [markdown]
# ### math
# Purpose: Provides mathematical functions like trigonometry, logarithms, etc.
# Common Functions:
#
# - math.sqrt(): Compute the square root
# - math.sin(), math.cos(): Trigonometric functions
# - math.pi: Mathematical constant π

# %% [markdown]
# ### random
#
# Purpose: Provides functions to generate random numbers, make random selections, and shuffle sequences.
# Common Functions:
# - random.randint(): Generate a random integer
# - random.choice(): Select a random element from a sequence
# - random.shuffle(): Shuffle a sequence in place

# %% [markdown]
# ### datetime
#
# Purpose: Provides classes for working with dates and times.
# Common Functions:
#
# - datetime.datetime.now(): Get the current date and time
# - datetime.timedelta: Represents the difference between two dates/times
# - datetime.date(): Create and manipulate dates

# %% [markdown]
# ### csv
#
# Purpose: Provides functions for reading and writing CSV (Comma Separated Values) files.
# Common Functions:
# - csv.reader(): Read data from a CSV file
# - csv.writer(): Write data to a CSV file

# %% [markdown]
# # files

# %% [markdown]
# ### YAML (text.csv)
#
# - Human-Readable:
# YAML's syntax is clean and easy to understand. It's formatted using indentation, similar to Python, which eliminates the need for brackets or tags.
#
# - Lightweight:
# It’s a concise format that avoids extra characters, making it simple and compact.
#
# - Flexible:
# YAML supports different types of data, such as strings, numbers, lists, dictionaries, and nested structures.
#
# - Widely Used:
# YAML is popular in tools and platforms like Docker Compose, Kubernetes, Ansible, GitHub Actions, and more.
